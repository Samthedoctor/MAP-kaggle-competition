# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/map-charting-student-math-misunderstandings/sample_submission.csv
# /kaggle/input/map-charting-student-math-misunderstandings/train.csv
# /kaggle/input/map-charting-student-math-misunderstandings/test.csv
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/config.json
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/merges.txt
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/LICENSE
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/README.md
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/tokenizer.json
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/vocab.json
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/tokenizer_config.json
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/model.safetensors
# /kaggle/input/qwen2.5-math/transformers/1.5b/1/generation_config.json
# /kaggle/input/my-map-inference-libs/nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/typing_extensions-4.15.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/requests-2.32.5-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/joblib-1.5.1-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/tqdm-4.67.1-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/peft-0.10.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/networkx-3.5-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl
# /kaggle/input/my-map-inference-libs/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/filelock-3.19.1-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/idna-3.10-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/urllib3-2.5.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/mpmath-1.3.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/hf_xet-1.1.8-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/jinja2-3.1.6-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/my-map-inference-libs/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/my-map-inference-libs/scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/my-map-inference-libs/scikit_learn-1.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/threadpoolctl-3.6.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/transformers-4.41.2-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl
# /kaggle/input/my-map-inference-libs/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/accelerate-0.30.1-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/packaging-25.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/huggingface_hub-0.34.4-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/sympy-1.14.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/regex-2025.7.34-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# /kaggle/input/my-map-inference-libs/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# /kaggle/input/my-map-inference-libs/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# /kaggle/input/my-map-inference-libs/fsspec-2025.7.0-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/certifi-2025.8.3-py3-none-any.whl
# /kaggle/input/my-map-inference-libs/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl
# /kaggle/input/my-map-inference-libs/torch-2.1.2-cp311-cp311-manylinux1_x86_64.whl
# /kaggle/input/map-finetune-24/label_mappings.json
# /kaggle/input/map-finetune-24/__results__.html
# /kaggle/input/map-finetune-24/__huggingface_repos__.json
# /kaggle/input/map-finetune-24/__notebook__.ipynb
# /kaggle/input/map-finetune-24/__output__.json
# /kaggle/input/map-finetune-24/custom.css
# /kaggle/input/map-finetune-24/__results___files/__results___7_1.png
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/merges.txt
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/training_args.bin
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/adapter_config.json
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/README.md
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/tokenizer.json
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/vocab.json
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen-finetuned-best-checkpoint/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10900/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2900/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8400/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5900/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2000/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3600/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2200/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11000/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-8300/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10300/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2300/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-400/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7400/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6600/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9900/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-9800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10000/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5600/rng_state.pth
# ...
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11100/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11100/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11100/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11100/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4000/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-3200/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-7500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-1000/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-4700/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-5200/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11900/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-11800/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-2600/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-10500/added_tokens.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/adapter_model.safetensors
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/merges.txt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/trainer_state.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/training_args.bin
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/adapter_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/README.md
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/tokenizer.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/vocab.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/tokenizer_config.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/scheduler.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/special_tokens_map.json
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/optimizer.pt
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/rng_state.pth
# /kaggle/input/map-finetune-24/qwen2_5-math-finetuned/checkpoint-6500/added_tokens.json

# %%
# IMPORTANT: Replace 'my-map-inference-libs' if you used a different name
# !pip install --no-index --find-links=/kaggle/input/my-map-inference-libs \
    bitsandbytes==0.43.1 \
    peft==0.10.0 \
    accelerate==0.30.1 \
    transformers==4.41.2 \
    triton==2.1.0 \
    scikit-learn==1.2.2

print("✅ Libraries installed from your personal offline dataset.")
# Out:
# Looking in links: /kaggle/input/my-map-inference-libs
# Processing /kaggle/input/my-map-inference-libs/bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl
# Processing /kaggle/input/my-map-inference-libs/peft-0.10.0-py3-none-any.whl
# Processing /kaggle/input/my-map-inference-libs/accelerate-0.30.1-py3-none-any.whl
# Processing /kaggle/input/my-map-inference-libs/transformers-4.41.2-py3-none-any.whl
# Processing /kaggle/input/my-map-inference-libs/triton-2.1.0-0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl
# Requirement already satisfied: scikit-learn==1.2.2 in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from bitsandbytes==0.43.1) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from bitsandbytes==0.43.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (7.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (4.67.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from peft==0.10.0) (0.33.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.2) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.41.2) (2.32.4)
# Processing /kaggle/input/my-map-inference-libs/tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from transformers==4.41.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.2.2) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.17.0->peft==0.10.0) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->bitsandbytes==0.43.1) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes==0.43.1) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes==0.43.1) (3.1.6)
# INFO: pip is looking at multiple versions of torch to determine which version is compatible with other requirements. This could take a while.
# Processing /kaggle/input/my-map-inference-libs/torch-2.1.2-cp311-cp311-manylinux1_x86_64.whl (from bitsandbytes==0.43.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch->bitsandbytes==0.43.1) (1.13.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Processing /kaggle/input/my-map-inference-libs/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from torch->bitsandbytes==0.43.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes==0.43.1) (12.5.82)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.41.2) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->bitsandbytes==0.43.1) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->bitsandbytes==0.43.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->bitsandbytes==0.43.1) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->bitsandbytes==0.43.1) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->bitsandbytes==0.43.1) (2024.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->bitsandbytes==0.43.1) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->bitsandbytes==0.43.1) (2024.2.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, tokenizers, transformers, accelerate, peft, bitsandbytes
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.2
#     Uninstalling tokenizers-0.21.2:
#       Successfully uninstalled tokenizers-0.21.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.52.4
#     Uninstalling transformers-4.52.4:
#       Successfully uninstalled transformers-4.52.4
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.8.1
#     Uninstalling accelerate-1.8.1:
#       Successfully uninstalled accelerate-1.8.1
#   Attempting uninstall: peft
#     Found existing installation: peft 0.15.2
#     Uninstalling peft-0.15.2:
#       Successfully uninstalled peft-0.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.1.2 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.1.2 which is incompatible.
# Successfully installed accelerate-0.30.1 bitsandbytes-0.43.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvtx-cu12-12.1.105 peft-0.10.0 tokenizers-0.19.1 torch-2.1.2 transformers-4.41.2 triton-2.1.0
# ✅ Libraries installed from your personal offline dataset.

# %%
import torch
import pandas as pd
import numpy as np
import json
from transformers import AutoModelForSequenceClassification, AutoTokenizer, BitsAndBytesConfig
from peft import PeftModel
from tqdm.auto import tqdm

# Define the paths to your trained model and mappings
# The folder name 'map-finetune-24' comes from the name of your training notebook
base_path = "/kaggle/input/map-finetune-24/"
model_path = base_path + "qwen-finetuned-best-checkpoint/"
mappings_path = base_path + "label_mappings.json"

print("✅ Paths defined.")
# Out:
# ✅ Paths defined.

# %%
# Load the label mappings
with open(mappings_path, 'r') as f:
    mappings = json.load(f)
    id_to_label = {int(k): v for k, v in mappings['id_to_label'].items()}

# --- CHANGE IS HERE ---
# Define base model and quantization
# Use the local path to the model you added as a data source
model_name = "/kaggle/input/qwen2.5-math/transformers/1.5b/1" 

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16
)

# Load the base model from the local path
base_model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    num_labels=len(id_to_label),
    device_map="auto"
)

# Load the tokenizer from the local path
tokenizer = AutoTokenizer.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
base_model.config.pad_token_id = tokenizer.pad_token_id


# Load the LoRA adapters and merge them into the base model
model = PeftModel.from_pretrained(base_model, model_path)
model.eval() # Set the model to evaluation mode

print("✅ Fine-tuned model and mappings loaded successfully from local files.")
# Out:
# Some weights of Qwen2ForSequenceClassification were not initialized from the model checkpoint at /kaggle/input/qwen2.5-math/transformers/1.5b/1 and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ✅ Fine-tuned model and mappings loaded successfully from local files.

# %%
# Load the test data
df_test = pd.read_csv("/kaggle/input/map-charting-student-math-misunderstandings/test.csv")

# Define the prompt template (must be identical to training)
prompt_template = """Analyze the student's reasoning for the following math problem.

### Question:
{QuestionText}

### Student's Answer Choice:
{MC_Answer}

### Student's Explanation:
{StudentExplanation}

### Analysis:"""

predictions = []
# Use tqdm for a progress bar
for _, row in tqdm(df_test.iterrows(), total=len(df_test)):
    # Format the prompt
    prompt = prompt_template.format(
        QuestionText=row['QuestionText'],
        MC_Answer=row['MC_Answer'],
        StudentExplanation=row['StudentExplanation']
    )
    
    # Tokenize the input
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True).to(model.device)
    
    # Get model predictions (logits)
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits

    # Get top 3 predictions
    top_3 = torch.topk(logits, 3).indices.squeeze().tolist()
    
    # Decode the predictions and join them
    pred_labels = [id_to_label[i] for i in top_3]
    predictions.append(" ".join(pred_labels))

print("✅ Predictions generated.")
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 2025-08-25 20:23:49.193089: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756153429.398867      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756153429.455799      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ Predictions generated.

# %%
# Create the submission DataFrame
submission_df = pd.DataFrame({
    'row_id': df_test['row_id'],
    'Category:Misconception': predictions
})

# Save to submission.csv
submission_df.to_csv('submission.csv', index=False)

print("✅ submission.csv created successfully!")
print("You can now submit your notebook.")
# Out:
# ✅ submission.csv created successfully!
# You can now submit your notebook.
